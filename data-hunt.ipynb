# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import statistics as stats
import matplotlib.pyplot as mp
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/practice/DataHunt/DSC.pdf
# /kaggle/input/practice/DataHunt/Features_4.csv
# /kaggle/input/practice/DataHunt/Driven_by_data.ipynb
# /kaggle/input/practice/DataHunt/Untitled.ipynb
# /kaggle/input/practice/DataHunt/Hint1.txt
# /kaggle/input/practice/DataHunt/Half Data Frame.csv
# /kaggle/input/practice/DataHunt/Features_14.csv
# /kaggle/input/practice/DataHunt/Features_0.csv
# /kaggle/input/practice/DataHunt/Features_6.csv
# /kaggle/input/practice/DataHunt/Targets.csv
# /kaggle/input/practice/DataHunt/Features_8.csv
# /kaggle/input/practice/DataHunt/new-workspace.jupyterlab-workspace
# /kaggle/input/practice/DataHunt/Features_2.csv
# /kaggle/input/practice/DataHunt/Hint2.txt
# /kaggle/input/practice/DataHunt/Features_10.csv
# /kaggle/input/practice/DataHunt/Features_12.csv
# /kaggle/input/practice/DataHunt/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# /kaggle/input/practice/DataHunt/.ipynb_checkpoints/Driven_by_data-checkpoint.ipynb
# ...

# %%
ft_0 = pd.read_csv(r"../input/practice/DataHunt/Features_0.csv",delimiter=";")
df_0= pd.DataFrame(ft_0)

# %%
ft_2 = pd.read_csv(r"../input/practice/DataHunt/Features_2.csv",delimiter=";")
df_2= pd.DataFrame(ft_2)
ft_4 = pd.read_csv(r"../input/practice/DataHunt/Features_4.csv",delimiter=";")
df_4= pd.DataFrame(ft_4)
ft_6 = pd.read_csv(r"../input/practice/DataHunt/Features_6.csv",delimiter=";")
df_6= pd.DataFrame(ft_6)
ft_8 = pd.read_csv(r"../input/practice/DataHunt/Features_8.csv",delimiter=";")
df_8= pd.DataFrame(ft_8)
ft_10 = pd.read_csv(r"../input/practice/DataHunt/Features_10.csv",delimiter=";")
df_10= pd.DataFrame(ft_10)
ft_12 = pd.read_csv(r"../input/practice/DataHunt/Features_12.csv",delimiter=";")
df_12= pd.DataFrame(ft_12)
ft_14 = pd.read_csv(r"../input/practice/DataHunt/Features_14.csv",delimiter=";")
df_14= pd.DataFrame(ft_14)
ft_target=pd.read_csv(r"../input/practice/DataHunt/Targets.csv",delimiter=";")
df_target=pd.DataFrame(ft_target)
half_data=pd.read_csv(r"../input/practice/DataHunt/Half Data Frame.csv",delimiter=";")
half_data_f=pd.DataFrame(half_data)
half_data.columns=['ID', 'Motorway', 'SR', 'NR', 'TR', 'VR', 'SUR1', 'SUR2', 'SUR3', 'UR', 'FR', 'OR','RR','BR', 'MR','CR']

# %%
Data_set=pd.concat([ft_0,ft_2,ft_4,ft_6,ft_8,ft_10,ft_12,ft_14,],axis=1)
Data_set=pd.concat([Data_set,half_data],axis=0)

# %%
Data_set.describe()
# Out:
#                ID             SR          NR          VR        SUR1  \
# count  195.000000     195.000000  195.000000  195.000000  101.000000
# mean    98.502564   -2721.822059    1.309274    1.917949    4.267327
# std     56.870478   80658.379606    2.579854    1.317384    3.509675
# min      1.000000 -361500.203152   -8.781940    0.000000    1.000000
# 25%     49.500000    -284.407894    1.000000    1.000000    2.000000
# 50%     99.000000     754.830387    1.000000    2.000000    2.000000
# 75%    147.500000    2614.869245    1.000000    3.000000    7.000000
# max    196.000000  500955.173438   16.890970    4.000000   14.000000
#
#              SUR2        SUR3          UR          OR          RR          BR  \
# count  195.000000  195.000000  158.000000  195.000000  164.000000  195.000000
# mean     5.384615    5.800000    0.784810   90.604163    2.250000    2.466667
# std      3.511508    3.305104    1.288567   32.884657    2.529276    2.624757
# ...

# %%
# Replacing Null values
Data_set.SUR1= Data_set.SUR1.fillna(stats.mode(Data_set.SUR1))
Data_set.UR=Data_set.UR.fillna(stats.mode(Data_set.UR))
Data_set.RR=Data_set.RR.fillna(2.250000)
Data_set.CR=Data_set.CR.fillna(stats.mode(Data_set.CR))
Data_set.isnull().sum()
Data_set.describe()
# Out:
#                ID             SR          NR          VR        SUR1  \
# count  195.000000     195.000000  195.000000  195.000000  195.000000
# mean    98.502564   -2721.822059    1.309274    1.917949    3.174359
# std     56.870478   80658.379606    2.579854    1.317384    2.763973
# min      1.000000 -361500.203152   -8.781940    0.000000    1.000000
# 25%     49.500000    -284.407894    1.000000    1.000000    2.000000
# 50%     99.000000     754.830387    1.000000    2.000000    2.000000
# 75%    147.500000    2614.869245    1.000000    3.000000    2.000000
# max    196.000000  500955.173438   16.890970    4.000000   14.000000
#
#              SUR2        SUR3          UR          OR          RR          BR  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     5.384615    5.800000    0.635897   90.604163    2.250000    2.466667
# std      3.511508    3.305104    1.199546   32.884657    2.318405    2.624757
# ...

# %%
#visualisng
dataplot=sns.heatmap(Data_set.corr(),annot=True)
mp.show()
#sns.pairplot(Data_set)
